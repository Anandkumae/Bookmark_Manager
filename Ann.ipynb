# %% [markdown]
# <a href="https://colab.research.google.com/github/Anandkumae/Bookmark_Manager/blob/main/Ann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import keras
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import sklearn.metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout

# %%
data=pd.read_csv("/content/sample_data/california_housing_train.csv")
data.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0

# %%
x=data.drop("median_house_value",axis=1)
y=data["median_house_value"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=Sequential()
model.add(Dense(30,activation="linear"))
model.add(Dense(15,activation="linear"))
model.add(Dense(18,activation="linear"))
model.compile(optimizer="adam",loss="mse")
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 47059746816.0000
# Epoch 2/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26048960512.0000
# Epoch 3/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26089652224.0000
# Epoch 4/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 25351618560.0000
# Epoch 5/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 24364879872.0000
# Epoch 6/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 21973182464.0000
# Epoch 7/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 19817615360.0000
# Epoch 8/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 16066069504.0000
# Epoch 9/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13165640704.0000
# Epoch 10/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11949318144.0000
# Epoch 11/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11307009024.0000
# Epoch 12/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11442249728.0000
# Epoch 13/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11559625728.0000
# Epoch 14/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 11512928256.0000
# Epoch 15/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11565900800.0000
# Epoch 16/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11493798912.0000
# Epoch 17/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11319591936.0000
# Epoch 18/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10994400256.0000
# Epoch 19/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11427607552.0000
# Epoch 20/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11348688896.0000
# Epoch 21/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11382713344.0000
# Epoch 22/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11158775808.0000
# Epoch 23/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10975902720.0000
# Epoch 24/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 11056929792.0000
# Epoch 25/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 11488568320.0000
# Epoch 26/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10715781120.0000
# Epoch 27/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10922029056.0000
# Epoch 28/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11129516032.0000
# Epoch 29/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10859058176.0000
# Epoch 30/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10914642944.0000
# Epoch 31/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10772985856.0000
# Epoch 32/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10705862656.0000
# Epoch 33/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10391832576.0000
# Epoch 34/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10558271488.0000
# Epoch 35/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10621636608.0000
# Epoch 36/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10678736896.0000
# Epoch 37/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10466195456.0000
# Epoch 38/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10872519680.0000
# Epoch 39/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10219859968.0000
# Epoch 40/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10346390528.0000
# Epoch 41/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10527941632.0000
# Epoch 42/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10172704768.0000
# Epoch 43/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10477122560.0000
# Epoch 44/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10252080128.0000
# Epoch 45/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10148030464.0000
# Epoch 46/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 10224293888.0000
# Epoch 47/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10157841408.0000
# Epoch 48/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10187778048.0000
# Epoch 49/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10092808192.0000
# Epoch 50/50
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9956172800.0000
